# %%
class CustomError(Exception):
    pass

# %%
raise CustomError("This is a custom error")
# Out:
# ---------------------------------------------------------------------------
# CustomError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 raise CustomError("This is a custom error")
#
# CustomError: This is a custom error

# %%
class CustomError(Exception):
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 class CustomError(Exception):
#       2     if x == 1:
#       3         raise CustomError("This is a custom error")
#
# Cell In[5], line 2, in CustomError()
#       1 class CustomError(Exception):
# ----> 2     if x == 1:
#       3         raise CustomError("This is a custom error")
#       4     else:
#
# NameError: name 'x' is not defined
